# %%
import numpy as np
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv("/Users/dj/Desktop/temp/Neural_Nutrition/FoodDB_data/foodb_2020_04_07_csv/Content.csv")
# Out:
# /var/folders/9r/pl8035cn4cjb59msrdwcrvhr0000gn/T/ipykernel_20668/13478461.py:1: DtypeWarning: Columns (4,5,6,7,8,9,13,14,21,22,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/dj/Desktop/temp/Neural_Nutrition/FoodDB_data/foodb_2020_04_07_csv/Content.csv")

# %%
df.head()
# Out:
#    id  source_id source_type  food_id orig_food_id orig_food_common_name  \
# 0   1          1    Nutrient        4           29                  Kiwi
# 1   2          1    Nutrient        6           53                 Onion
# 2   3          1    Nutrient        6           53                 Onion
# 3   4          1    Nutrient        9           55                Chives
# 4   5          1    Nutrient       11           70                Cashew
#
#                       orig_food_scientific_name orig_food_part orig_source_id  \
# 0  Actinidia chinensis PLANCHON [Actinidiaceae]          Fruit            FAT
# 1                    Allium cepa L. [Liliaceae]           Bulb            FAT
# 2                    Allium cepa L. [Liliaceae]           Leaf            FAT
# 3           Allium schoenoprasum L. [Liliaceae]           Leaf            FAT
# 4     Anacardium occidentale L. [Anacardiaceae]          Fruit            FAT
#
# ...

# %%
print(df.shape)
# Out:
# (5145532, 26)

# %%
df.columns
# Out:
# Index(['id', 'source_id', 'source_type', 'food_id', 'orig_food_id',
#        'orig_food_common_name', 'orig_food_scientific_name', 'orig_food_part',
#        'orig_source_id', 'orig_source_name', 'orig_content', 'orig_min',
#        'orig_max', 'orig_unit', 'orig_citation', 'citation', 'citation_type',
#        'creator_id', 'updater_id', 'created_at', 'updated_at', 'orig_method',
#        'orig_unit_expression', 'standard_content', 'preparation_type',
#        'export'],
#       dtype='object')

# %%
df.loc[:, ['orig_food_common_name', 'orig_food_part', 'orig_source_id', 'orig_source_name', 'orig_content', 'orig_min',
       'orig_max', 'orig_unit']].head(10)
# Out:
#   orig_food_common_name orig_food_part orig_source_id orig_source_name  \
# 0                  Kiwi          Fruit            FAT              FAT
# 1                 Onion           Bulb            FAT              FAT
# 2                 Onion           Leaf            FAT              FAT
# 3                Chives           Leaf            FAT              FAT
# 4                Cashew          Fruit            FAT              FAT
# 5                Cashew           Leaf            FAT              FAT
# 6                Cashew           Seed            FAT              FAT
# 7             Pineapple          Fruit            FAT              FAT
# 8                  Dill          Plant            FAT              FAT
# 9                  Dill           Seed            FAT              FAT
#
#    orig_content  orig_min  orig_max orig_unit
# 0       1955.00      70.0    3840.0   mg/100g
# 1       1853.95     100.0    3607.9   mg/100g
# 2       4150.00     600.0    7700.0   mg/100g
# ...

# %%
df['orig_food_part'].unique()
# Out:
# array(['Fruit', 'Bulb', 'Leaf', 'Seed', 'Plant', 'Root', 'Shoot', 'Stem',
#        'Flower', 'Latex Exudate', 'Bark', 'Silk Stigma Style', 'Rhizome',
#        'Stem Bark', 'Sprout Seedling', 'Pericarp', 'Hay', 'Aril', 'Twig',
#        'Herb', 'Pt', 'Tuber', 'Bud', 'Hull Husk', 'Pith', nan, 'Seed Oil',
#        'Essential Oil', 'Epidermis', 'Fruit Juice', 'Leaf Essent. Oil',
#        'Gum', 'Resin, Exudate, Sap', 'Seed Essent. Oil',
#        'Shoot Essent. Oil', 'Root Essent. Oil', 'Tissue Culture',
#        'Stem Essent. Oil', 'Leaf Wax', 'Petiole', 'Oil', 'Bran', 'Embryo',
#        'Inflorescence', 'Fruit Essent. Oil', 'Root Bark', 'Anther',
#        'Seed Coat', 'Endosperm', 'Cotyledon', 'Pollen Or Spore',
#        'Flower Essent. Oil', 'Bark Essent. Oil', 'Wood Essent. Oil',
#        'Pericarp Essent. Oil', 'Exocarp', 'Branches', 'Wood',
#        'Rhizome Essent. Oil', 'Calyx', 'Hs', 'Testa', 'Hypocotyl',
#        'Nodule', 'Leaf Diffusate', 'Protoplast', 'Caryopsis',
# ...

# %%
df['orig_food_part'].value_counts().head(25)
# Out:
# orig_food_part
# Fruit                  8167
# Leaf                   8041
# Seed                   6806
# Plant                  4405
# Root                   2252
# Shoot                  1491
# Essential Oil          1113
# Flower                  724
# Bulb                    588
# Seed Oil                499
# Leaf Essent. Oil        487
# Sprout Seedling         433
# Rhizome                 422
# Stem                    395
# Seed Essent. Oil        394
# Fruit Juice             350
# Bark                    343
# Tuber                   332
# Pericarp                324
# Tissue Culture          288
# Fruit Essent. Oil       229
# Silk Stigma Style       203
# Shoot Essent. Oil       181
# Rhizome Essent. Oil     143
# Pt                      142
# Name: count, dtype: int64

# %%
df['orig_food_part'].value_counts().tail(25)
# Out:
# orig_food_part
# Bark Essent. Oil    22
# Leaf Diffusate      21
# Heart Wood          19
# Et                  18
# Hay                 18
# Stem Essent. Oil    17
# Twig                11
# Cob                  9
# Gum                  9
# Pith                 9
# Protoplast           7
# Wax                  6
# Nodule               6
# Fruit Epidermis      5
# Epidermis            5
# Exocarp              5
# Thallus              5
# Bran                 4
# Leaf Wax             3
# Branches             2
# Tuber Epidermis      2
# Caryopsis            1
# Na                   1
# Wood Essent. Oil     1
# Mycelium             1
# Name: count, dtype: int64

# %%
df['orig_food_common_name'].value_counts().head(25)
# Out:
# orig_food_common_name
# Lipid from Arabidopsis (PathBank)         2043150
# Endogenous compounds from human (HMDB)    1230412
# Tea                                         11816
# Milk, skimmed                                3002
# Milk, 3.25% fat                              2903
# Milk, 2% fat                                 2717
# Other fruits                                 2649
# Milk, 1% fat                                 2613
# Herbs, condiments and spices                 2569
# Bell Pepper                                  1840
# Alliums                                      1740
# Fungi                                        1722
# Milk, raw                                    1530
# Tea, leaves                                  1414
# Tea, ready-to-drink                          1351
# Cereals and bakery products                  1310
# Coffee                                       1229
# Other green vegetables                        937
# ...

# %% [markdown]
# ## CSV

# %%
import os
import pandas as pd

# Directory containing the CSV files
input_directory = '/Users/dj/Desktop/temp/Neural_Nutrition/FoodDB_data/foodb_2020_04_07_csv'

# Dictionary to store DataFrames
dataframes = {}

# Loop through all files in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith('.csv'):

        # get the current file
        print(filename)
        
        # Full path of the CSV file
        csv_file_path = os.path.join(input_directory, filename)
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(csv_file_path)

                # Use the filename without extension as the key
        df_name = os.path.splitext(filename)[0]
        
        # Store the DataFrame in the dictionary
        dataframes[df_name] = df


print("All files have been converted to Parquet format.")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# CompoundSynonym.csv
# PdbIdentifier.csv
# Pathway.csv
# Compound.csv
# /var/folders/9r/pl8035cn4cjb59msrdwcrvhr0000gn/T/ipykernel_2220/3212510073.py:21: DtypeWarning: Columns (3,4,5,6,12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
# CompoundsFlavor.csv
# AccessionNumber.csv
# CompoundsEnzyme.csv
# CompoundsPathway.csv
# CompoundExternalDescriptor.csv
# PfamMembership.csv
# Enzyme.csv
# Nutrient.csv
# Flavor.csv
# ...

# %%
content = dataframes.get('Content')
food = dataframes.get('Food')
compound = dataframes.get('Compound')
nutrient = dataframes.get('Nutrient')

# %%
food.head()
# Out:
#    id           name                 name_scientific  \
# 0   1       Angelica                Angelica keiskei
# 1   2  Savoy cabbage  Brassica oleracea var. sabauda
# 2   3  Silver linden                  Tilia argentea
# 3   4           Kiwi             Actinidia chinensis
# 4   5         Allium                          Allium
#
#                                          description   itis_id  \
# 0  Angelica is a genus of about 60 species of tal...       NaN
# 1  Savoy cabbage (Brassica oleracea convar. capit...       NaN
# 2  Tilia tomentosa (Silver Lime in the UK and Sil...  845789.0
# 3  The kiwifruit, often shortened to kiwi in many...  506775.0
# 4  Allium haematochiton is a species of wild onio...   42634.0
#
#            wikipedia_id picture_file_name picture_content_type  \
# 0              Angelica             1.jpg           image/jpeg
# 1         Savoy cabbage             2.jpg           image/jpeg
# 2       Tilia tomentosa             3.jpg           image/jpeg
# ...

# %%
for name in dataframes.keys():
    temp_df = dataframes.get(name)
    print(f'{name} has shape {temp_df.shape[0]}')
# Out:
# CompoundSynonym has shape 171240
# PdbIdentifier has shape 0
# Pathway has shape 97
# Compound has shape 70477
# CompoundsFlavor has shape 11775
# AccessionNumber has shape 1424
# CompoundsEnzyme has shape 105089
# CompoundsPathway has shape 1604
# CompoundExternalDescriptor has shape 4009
# PfamMembership has shape 0
# Enzyme has shape 1744
# Nutrient has shape 39
# Flavor has shape 883
# Food has shape 992
# EnzymeSynonym has shape 0
# HealthEffect has shape 1435
# Sequence has shape 0
# OntologyTerm has shape 4370
# FoodTaxonomy has shape 889
# OntologySynonym has shape 1669
# CompoundSubstituent has shape 95299
# CompoundAlternateParent has shape 50691
# MapItemsPathway has shape 0
# Content has shape 5145532
# Reference has shape 31778
# CompoundsHealthEffect has shape 11062
# NcbiTaxonomyMap has shape 242
# Pfam has shape 0
# CompoundOntologyTerm has shape 1587712

# %%
dataframes.get('Compound').head()
# Out:
#    id  public_id                                     name moldb_iupac state  \
# 0   4  FDB000004      Cyanidin 3-(6''-acetyl-galactoside)         NaN   low
# 1  13  FDB000013      Cyanidin 3-(6''-succinyl-glucoside)         NaN   low
# 2  14  FDB000014  Pelargonidin 3-(6''-succinyl-glucoside)      liquid   low
# 3  24  FDB000024   Petunidin 3-O-(6''-acetyl-galactoside)         NaN   low
# 4  25  FDB000025      Peonidin 3-(6''-acetyl-galactoside)         NaN   low
#
#                                   annotation_quality  description  \
# 0  Constituent of the leaves of Nymphaea alba [CC...  350602-26-5
# 1  Constituent of Phragmites australis [CCD]. Cya...  216692-08-9
# 2  Pelargonidin 3-(6''-succinyl-glucoside) is a m...          NaN
# 3  Petunidin 3-o-(6''-acetyl-galactoside) is a me...          NaN
# 4  Peonidin 3-(6''-acetyl-galactoside) is a membe...      75-07-0
#
#                                           cas_number  \
# 0  [H][C@]1(COC(C)=O)O[C@@]([H])(OC2=CC3=C(O)C=C(...
# ...

# %%
# Loop through each DataFrame in the dictionary
for df_name, df in dataframes.items():
    print(f"{df_name} has id columns: {df.columns[np.where(df.columns.str.contains('id'))[0]]}")
# Out:
# CompoundSynonym has id columns: Index(['id', 'source_id'], dtype='object')
# PdbIdentifier has id columns: Index(['id', 'compound_id', 'pdb_id'], dtype='object')
# Pathway has id columns: Index(['id', 'smpdb_id', 'kegg_map_id'], dtype='object')
# Compound has id columns: Index(['id', 'public_id'], dtype='object')
# CompoundsFlavor has id columns: Index(['id', 'compound_id', 'flavor_id', 'creator_id', 'updater_id',
#        'source_id'],
#       dtype='object')
# AccessionNumber has id columns: Index(['id', 'compound_id', 'source_id'], dtype='object')
# CompoundsEnzyme has id columns: Index(['id', 'compound_id', 'enzyme_id', 'creator_id', 'updater_id'], dtype='object')
# CompoundsPathway has id columns: Index(['id', 'compound_id', 'pathway_id', 'creator_id', 'updater_id'], dtype='object')
# CompoundExternalDescriptor has id columns: Index(['id', 'external_id', 'compound_id', 'creator_id', 'updater_id'], dtype='object')
# ...

# %%
import numpy as np

test = dataframes.get('Compound')
np.where(test.columns.str.contains('id'))[0]
print(test.columns[np.where(test.columns.str.contains('id'))[0]])
# Out:
# Index(['id', 'public_id'], dtype='object')

# %%
test.columns.str.contains('id')
# Out:
# array([ True,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])
